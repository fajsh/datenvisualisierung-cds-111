# %% [markdown]
# # Entwurf Visualisierungen

# %%
# Import necessary libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Import dataset
data = pd.read_excel('dataset.xlsx')
df = data.copy()

# %%
# Drop unnecessary rows, columns
df = df.iloc[18:]
df = df.iloc[:-22]
df = df.drop(columns=['Unnamed: 18', 'Unnamed: 19'])

# %%
df.head()
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 18  2025-01-01 00:00:00      26.21     18.266     44.476      70.99
# 19  2025-01-08 00:00:00     37.651     67.612    105.263     70.823
# 20  2025-01-15 00:00:00     40.497     107.22    147.717     71.118
# 21  2025-01-22 00:00:00     35.939     95.777    131.716     71.038
# 22  2025-01-29 00:00:00     36.514     62.409     98.923     71.008
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 18      9.895      1.221      6.197    132.779     26.509      106.27
# 19     10.702      1.561      2.899    191.248      5.961     185.287
# 20     12.332      0.741      7.296    239.204      8.119     231.085
# 21     12.224      1.183      3.598    219.759      3.553     216.206
# 22     12.437      0.909     13.493     196.77     10.749     186.021
#
#    Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# ...

# %%
# Rename columns
df.columns = ['Datum','Laufwerke', 'Speicherwerke', 'Total Hydraulisch', 'Kernkraftwerke', 'Thermisch', 'Windkraft', 'Photovoltaik', 'Total Erneuerbar', 'Verbrauch Speicherpumpen','Nettoerzeugung Total', 'Einfuhr', 'Ausfuhr', 'Überschuss','Landesverbrauch', 'Mittlere Tagestemperatur','Wasserführung Rhein', 'Wasserführung in %']

# %%
# Convert columns to numeric and round
for col in df.columns[1:15]:
    df[col] = pd.to_numeric(df[col], errors='coerce').round(1)
for col in df.columns[15:17]:
    df[col] = pd.to_numeric(df[col], errors='coerce').round(0)
# Convert 'Wasserführung in %' to percentage and round
df['Wasserführung in %'] = (pd.to_numeric(df['Wasserführung in %'], errors='coerce') * 100).round(0)
# Convert 'Datum' to datetime
df['Datum'] = pd.to_datetime(df['Datum']).dt.date

# %%
df
# Out:
#          Datum  Laufwerke  Speicherwerke  Total Hydraulisch  Kernkraftwerke  \
# 18  2025-01-01       26.2           18.3               44.5            71.0
# 19  2025-01-08       37.7           67.6              105.3            70.8
# 20  2025-01-15       40.5          107.2              147.7            71.1
# 21  2025-01-22       35.9           95.8              131.7            71.0
# 22  2025-01-29       36.5           62.4               98.9            71.0
# 23  2025-02-05       33.7           92.1              125.8            71.1
# 24  2025-02-12       31.7           85.7              117.4            70.7
# 25  2025-02-19       30.3           76.3              106.6            69.2
# 26  2025-02-26       28.5           59.8               88.3            70.9
# 27  2025-03-05       27.9           48.9               76.8            70.8
# 28  2025-03-12       30.2           45.2               75.4            70.7
# ...
